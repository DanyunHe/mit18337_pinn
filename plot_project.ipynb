# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.io

# %%
exact_soln = scipy.io.loadmat('C:/Users/Jiayin/Documents/GitHub/mit18337_pinn/Data/burgers_shock.mat')

# %%
t=exact_soln["t"]  #length 100
x=exact_soln["x"]  #length 256
exact=exact_soln["usol"][:,:45]

# %%
plt.figure(figsize = (20,4))
plt.imshow(exact, origin="lower",extent=[0, 0.45, -1, 1],aspect=0.08,cmap='plasma')
plt.colorbar()
plt.xlabel("t", fontsize=15)
plt.ylabel("x", fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.axvline(x=0.1, color="white")
plt.axvline(x=0.2, color="white")
plt.axvline(x=0.3, color="white")
plt.axvline(x=0.4, color="white")
plt.title("one-dimensional Burger's equation exact solution u(t,x)", fontsize=15)
# Out:
# Text(0.5, 1.0, "one-dimensional Burger's equation exact solution u(t,x)")

# %%
fig = plt.figure(figsize = (15,13))

plt.subplot(2, 2, 1)
plt.plot(x,exact[:,10])
plt.xlabel("x", fontsize=15)
plt.ylabel("u(t,x)", fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.title("t=0.10", fontsize=15)
plt.grid()

plt.subplot(2, 2, 2)
plt.plot(x,exact[:,20])
plt.xlabel("x", fontsize=15)
plt.ylabel("u(t,x)", fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.title("t=0.20", fontsize=15)
plt.grid()

plt.subplot(2, 2, 3)
plt.plot(x,exact[:,30])
plt.xlabel("x", fontsize=15)
plt.ylabel("u(t,x)", fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.title("t=0.30", fontsize=15)
plt.grid()

plt.subplot(2, 2, 4)
plt.plot(x,exact[:,40])
plt.xlabel("x", fontsize=15)
plt.ylabel("u(t,x)", fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.title("t=0.40", fontsize=15)
plt.grid()

plt.show()

# %%
#t=0.1 sampling uniform locations
sample_uniform_1=np.genfromtxt(r"C:\Users\Jiayin\Documents\GitHub\mit18337_pinn\output_jiayin\uniforms\PINN_sample_x_u_uniform_sampling_32_0.1_1_jiayin.txt", delimiter=',')
x_sample_uniform_1=sample_uniform_1[:,0]
u_sample_uniform_1=sample_uniform_1[:,1]

# %%
fig = plt.figure(figsize = (36,8))


plt.subplot(1, 3, 1)
plt.plot(x,exact[:,10], "r", label="exact solution",linewidth=5)
plt.plot(x_sample_uniform_1,u_sample_uniform_1, 'k*', markersize=7, label="$N_n=250$ uniformly \nsampled training data")
plt.xlabel("x", fontsize=15)
plt.ylabel("u(t,x)", fontsize=20)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.title("(a) t=0.10", fontsize=15)
plt.legend(fontsize=15)
plt.grid()

plt.subplot(1, 3, 2)
plt.plot(x,exact[:,20], "r", label="exact solution",linewidth=5)
plt.plot(x,exact[:,20], "b--", label="predicted solution",linewidth=5)
plt.xlabel("x", fontsize=15)
plt.ylabel("u(t,x)", fontsize=20)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.title("(b) t=0.20", fontsize=15)
plt.legend(fontsize=15)
plt.grid()

plt.subplot(1, 3, 3)
plt.plot(x,exact[:,30], "r", label="exact solution",linewidth=5)
plt.plot(x,exact[:,30], "b--", label="predicted solution",linewidth=5)
plt.xlabel("x", fontsize=15)
plt.ylabel("u(t,x)", fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.title("(c) t=0.30", fontsize=20)
plt.legend(fontsize=15)
plt.grid()




plt.show()

# %%
plt.figure(figsize = (6,4))
plt.plot(x,exact[:,30])
plt.xlabel("x", fontsize=15)
plt.ylabel("u(t,x)", fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.title("t=0.30", fontsize=15)
# Out:
# Text(0.5, 1.0, 't=0.30')

# %%
#dt=0.1 vary stages
stage_dt1=np.genfromtxt(r"C:\Users\Jiayin\Documents\GitHub\mit18337_pinn\output_jiayin\table\PINN_error_vary_q_dt_jiayin_0.1.txt", delimiter=' ')
stage_dt1_stage=stage_dt1[:,0]
stage_dt1_error=stage_dt1[:,2]
stage_dt1_time=stage_dt1[:,3]

#dt=0.2 vary stages
stage_dt2=np.genfromtxt(r"C:\Users\Jiayin\Documents\GitHub\mit18337_pinn\output_jiayin\table\PINN_error_vary_q_dt_jiayin_0.2.txt", delimiter=' ')
stage_dt2_stage=stage_dt2[:,0]
stage_dt2_error=stage_dt2[:,2]
stage_dt2_time=stage_dt2[:,3]

# %%
loss_dt1_1=np.genfromtxt(r"C:\Users\Jiayin\Documents\GitHub\mit18337_pinn\output_jiayin\table\PINN_iter_loss_MSE_1_0.1_jiayin.txt", delimiter=' ')
loss_dt1_1_iter=loss_dt1_1[:,0]
loss_dt1_1_loss=loss_dt1_1[:,1]

loss_dt1_4=np.genfromtxt(r"C:\Users\Jiayin\Documents\GitHub\mit18337_pinn\output_jiayin\table\PINN_iter_loss_MSE_4_0.1_jiayin.txt", delimiter=' ')
loss_dt1_4_iter=loss_dt1_4[:,0]
loss_dt1_4_loss=loss_dt1_4[:,1]

loss_dt1_32=np.genfromtxt(r"C:\Users\Jiayin\Documents\GitHub\mit18337_pinn\output_jiayin\table\PINN_iter_loss_MSE_32_0.1_jiayin.txt", delimiter=' ')
loss_dt1_32_iter=loss_dt1_32[:,0]
loss_dt1_32_loss=loss_dt1_32[:,1]

loss_dt1_100=np.genfromtxt(r"C:\Users\Jiayin\Documents\GitHub\mit18337_pinn\output_jiayin\table\PINN_iter_loss_MSE_100_0.1_jiayin.txt", delimiter=' ')
loss_dt1_100_iter=loss_dt1_100[:,0]
loss_dt1_100_loss=loss_dt1_100[:,1]

loss_dt2_1=np.genfromtxt(r"C:\Users\Jiayin\Documents\GitHub\mit18337_pinn\output_jiayin\table\PINN_iter_loss_MSE_1_0.2_jiayin.txt", delimiter=' ')
loss_dt2_1_iter=loss_dt2_1[:,0]
loss_dt2_1_loss=loss_dt2_1[:,1]

loss_dt2_4=np.genfromtxt(r"C:\Users\Jiayin\Documents\GitHub\mit18337_pinn\output_jiayin\table\PINN_iter_loss_MSE_4_0.2_jiayin.txt", delimiter=' ')
loss_dt2_4_iter=loss_dt2_4[:,0]
loss_dt2_4_loss=loss_dt2_4[:,1]

loss_dt2_32=np.genfromtxt(r"C:\Users\Jiayin\Documents\GitHub\mit18337_pinn\output_jiayin\table\PINN_iter_loss_MSE_32_0.2_jiayin.txt", delimiter=' ')
loss_dt2_32_iter=loss_dt2_32[:,0]
loss_dt2_32_loss=loss_dt2_32[:,1]

loss_dt2_100=np.genfromtxt(r"C:\Users\Jiayin\Documents\GitHub\mit18337_pinn\output_jiayin\table\PINN_iter_loss_MSE_100_0.2_jiayin.txt", delimiter=' ')
loss_dt2_100_iter=loss_dt2_100[:,0]
loss_dt2_100_loss=loss_dt2_100[:,1]

# %%
fig = plt.figure(figsize = (24,18))


plt.subplot(2, 2, 1)
plt.semilogy(stage_dt1_stage,stage_dt1_error,"b-*", label="$\Delta t=0.1$")
plt.semilogy(stage_dt2_stage,stage_dt2_error,"r-*", label="$\Delta t=0.2$")
plt.xlabel("number of Runge-Kutta stages q", fontsize=15)
plt.ylabel("relative $L_2$ error", fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.title("(a) Relative $L_2$ error", fontsize=20)
plt.legend(fontsize=15)
plt.grid()

plt.subplot(2, 2, 2)
plt.semilogy(stage_dt1_stage,stage_dt1_time,"b-*", label="$\Delta t=0.1$")
plt.semilogy(stage_dt2_stage,stage_dt2_time,"r-*", label="$\Delta t=0.2$")
plt.xlabel("number of Runge-Kutta stages q", fontsize=15)
plt.ylabel("Computation time (s)", fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.title("(b) Computation time", fontsize=20)
plt.legend(fontsize=15)
plt.grid()

plt.subplot(2, 2, 3)
plt.semilogy(loss_dt1_1_iter,loss_dt1_1_loss,"-", label="$q=1$")
plt.semilogy(loss_dt1_4_iter,loss_dt1_4_loss,"-", label="$q=4$")
plt.semilogy(loss_dt1_32_iter,loss_dt1_32_loss,"-", label="$q=32$")
plt.semilogy(loss_dt1_100_iter,loss_dt1_100_loss,"-", label="$q=100$")
plt.xlabel("number of iterations", fontsize=15)
plt.ylabel("loss", fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.title("(c) Loss, $\Delta t=0.1$", fontsize=20)
plt.legend(fontsize=15)
plt.grid()

plt.subplot(2, 2, 4)
plt.semilogy(loss_dt2_1_iter,loss_dt2_1_loss,"-", label="$q=1$")
plt.semilogy(loss_dt2_4_iter,loss_dt2_4_loss,"-", label="$q=4$")
plt.semilogy(loss_dt2_32_iter,loss_dt2_32_loss,"-", label="$q=32$")
plt.semilogy(loss_dt2_100_iter,loss_dt2_100_loss,"-", label="$q=100$")
plt.xlabel("number of iterations", fontsize=15)
plt.ylabel("loss", fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.title("(d) Loss, $\Delta t=0.2$", fontsize=20)
plt.legend(fontsize=15)
plt.grid()

# %%
fig = plt.figure(figsize = (24,8))

plt.subplot(1, 2, 1)
plt.semilogy(loss_dt1_1_iter,loss_dt1_1_loss,"-", label="$q=1$")
plt.semilogy(loss_dt1_4_iter,loss_dt1_4_loss,"-", label="$q=4$")
plt.semilogy(loss_dt1_32_iter,loss_dt1_32_loss,"-", label="$q=32$")
plt.semilogy(loss_dt1_100_iter,loss_dt1_100_loss,"-", label="$q=100$")
plt.xlabel("number of iterations", fontsize=15)
plt.ylabel("loss", fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.title("(a) Loss, $\Delta t=0.1$", fontsize=20)
plt.legend(fontsize=15)
plt.grid()

plt.subplot(1, 2, 2)
plt.semilogy(loss_dt2_1_iter,loss_dt2_1_loss,"-", label="$q=1$")
plt.semilogy(loss_dt2_4_iter,loss_dt2_4_loss,"-", label="$q=4$")
plt.semilogy(loss_dt2_32_iter,loss_dt2_32_loss,"-", label="$q=32$")
plt.semilogy(loss_dt2_100_iter,loss_dt2_100_loss,"-", label="$q=100$")
plt.xlabel("number of iterations", fontsize=15)
plt.ylabel("loss", fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.title("(b) Loss, $\Delta t=0.2$", fontsize=20)
plt.legend(fontsize=15)
plt.grid()
